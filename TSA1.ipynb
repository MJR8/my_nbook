# %%
import pandas as pd
import seaborn as sns

# %%
tsa=pd.read_csv('tsa_claims1.csv')
tsa.head()
# Out:
# C:\Users\2518533\AppData\Local\Temp\ipykernel_8992\882036362.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   tsa=pd.read_csv('tsa_claims1.csv')
#     Claim Number Date Received    Incident Date Airport Code  \
# 0       0909802M      4-Jan-02  12/12/2002 0:00          EWR
# 1       0202445M      4-Feb-02  11/26/2003 0:00          STL
# 2       0909816M      7-Feb-02    1/6/2003 0:00          MIA
# 3  2005032379513     18-Feb-02    2/5/2005 0:00          MCO
# 4  2005032479636     18-Feb-02   2/17/2005 0:00          CAK
#
#                       Airport Name                   Airline Name  \
# 0     Newark International Airport           Continental Airlines
# 1  Lambert St. Louis International              American Airlines
# 2      Miami International Airport              American Airlines
# 3    Orlando International Airport                   Delta (Song)
# ...

# %%
tsa.duplicated(subset=['Claim Amount','Item'], keep='first')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 94843     True
# 94844    False
# 94845     True
# 94846     True
# 94847    False
# Length: 94848, dtype: bool

# %%
tsa.drop_duplicates(subset=['Claim Amount','Item', 'Claim Number'], keep='first')
# Out:
#         Claim Number Date Received     Incident Date Airport Code  \
# 0           0909802M      4-Jan-02   12/12/2002 0:00          EWR
# 1           0202445M      4-Feb-02   11/26/2003 0:00          STL
# 2           0909816M      7-Feb-02     1/6/2003 0:00          MIA
# 3      2005032379513     18-Feb-02     2/5/2005 0:00          MCO
# 4      2005032479636     18-Feb-02    2/17/2005 0:00          CAK
# ...              ...           ...               ...          ...
# 94843  2010010567195     31-Dec-09   12/14/2009 0:00          EWR
# 94844  2010010667196     31-Dec-09   12/17/2009 7:55          BWI
# 94845  2010010667198     31-Dec-09   12/15/2009 0:00          SMF
# 94846  2010010667199     31-Dec-09  12/16/2009 10:00          ENV
# 94847  2009122866807     31-Dec-09   11/21/2009 9:20          JFK
#
#                                       Airport Name  \
# 0                     Newark International Airport
# 1                  Lambert St. Louis International
# ...

# %%
tsa.dropna()
# Out:
#         Claim Number Date Received     Incident Date Airport Code  \
# 0           0909802M      4-Jan-02   12/12/2002 0:00          EWR
# 1           0202445M      4-Feb-02   11/26/2003 0:00          STL
# 2           0909816M      7-Feb-02     1/6/2003 0:00          MIA
# 3      2005032379513     18-Feb-02     2/5/2005 0:00          MCO
# 4      2005032479636     18-Feb-02    2/17/2005 0:00          CAK
# ...              ...           ...               ...          ...
# 94843  2010010567195     31-Dec-09   12/14/2009 0:00          EWR
# 94844  2010010667196     31-Dec-09   12/17/2009 7:55          BWI
# 94845  2010010667198     31-Dec-09   12/15/2009 0:00          SMF
# 94846  2010010667199     31-Dec-09  12/16/2009 10:00          ENV
# 94847  2009122866807     31-Dec-09   11/21/2009 9:20          JFK
#
#                                       Airport Name  \
# 0                     Newark International Airport
# 1                  Lambert St. Louis International
# ...

# %%
grop=tsa.groupby(by=['Claim Type']).count()
grop
# Out:
#                          Claim Number  Date Received  Incident Date  \
# Claim Type
# Employee Loss (MPCECA)            308            308            308
# Motor Vehicle                       6              6              6
# Passenger Property Loss         60265          60265          60265
# Passenger Theft                   331            331            331
# Personal Injury                   208            208            208
# Property Damage                 33730          33730          33730
#
#                          Airport Code  Airport Name  Airline Name  Claim Site  \
# Claim Type
# Employee Loss (MPCECA)            308           308           308         308
# Motor Vehicle                       6             6             6           6
# Passenger Property Loss         60265         60265         60265       60265
# Passenger Theft                   331           331           331         331
# ...

# %% [markdown]
# # •	What is the most common type of insurance claim?
# Passenger Property loss

# %%
site=tsa.groupby(by=['Claim Site']).count()
site
# Out:
#                  Claim Number  Date Received  Incident Date  Airport Code  \
# Claim Site
# Checked Baggage         80553          80553          80553         80553
# Checkpoint              14013          14013          14013         14013
# Motor Vehicle               2              2              2             2
# Other                     280            280            280           280
#
#                  Airport Name  Airline Name  Claim Type   Item  Claim Amount  \
# Claim Site
# Checked Baggage         80553         80553       80553  80553         80553
# Checkpoint              14013         14013       14013  14013         14013
# Motor Vehicle               2             2           2      2             2
# Other                     280           280         280    280           280
#
#                  Status  Close Amount  Disposition
# Claim Site
# Checked Baggage   80553         80553        80553
# Checkpoint        14013         14013        14013
# ...

# %% [markdown]
# # •	Which claim site within the airport are claims most commonly filed for?
# Checked Baggage

# %%
claim=tsa.groupby(by=['Claim Site','Claim Type']).count()
claim
# Out:
#                                          Claim Number  Date Received  \
# Claim Site      Claim Type
# Checked Baggage Employee Loss (MPCECA)            275            275
#                 Motor Vehicle                       4              4
#                 Passenger Property Loss         53364          53364
#                 Passenger Theft                   294            294
#                 Personal Injury                    89             89
#                 Property Damage                 26527          26527
# Checkpoint      Employee Loss (MPCECA)             32             32
#                 Motor Vehicle                       1              1
#                 Passenger Property Loss          6740           6740
#                 Passenger Theft                    36             36
#                 Personal Injury                   112            112
#                 Property Damage                  7092           7092
# ...

# %% [markdown]
# # •	What type of claim is made most at each claim site?
# Checked Baggage: Passenger Property Loss
# Motor Vehicle: Passenger Property Loss
# checkpoint: Property Damage

# %%
claimamt=tsa['Claim Amount'].mode()
claimamt
# Out:
# 0    100.0
# Name: Claim Amount, dtype: float64

# %% [markdown]
# # •	What is the typical claim amount?
# 100,0

# %%
# Count total claims
total_claims = tsa.shape[0]

approved_claims = tsa[tsa['Status'] == 'Approved'].shape[0]

approval_rate = (approved_claims / total_claims) * 100 if total_claims > 0 else 0

approval_rate
# Out:
# 24.425396423751685

# %% [markdown]
# # •	What is the overall claim approval rate for the entire U.S.?

# %% [markdown]
# 24.43%
